# %%
# timeモジュールをインポート
import time

# 現在時刻をUNIXタイムスタンプで取得
print(time.time())

# 現在時刻を日時のフォーマットで取得
print(time.strftime("%Y年%m月%d日%H時%M分%S秒", time.localtime()))
# Out:
# 1772540384.421613
# 2026年03月03日12時19分44秒

# %%
# !rm /etc/localtime
# !ln -s /usr/share/zoneinfo/Asia/Tokyo /etc/localtime
# !date
# Out:
# Tue Mar  3 09:21:14 PM JST 2026

# %%
# timeモジュールをインポート
import time

# 現在時刻をUNIXタイムスタンプで取得
print(time.time())
# Out:
# 1772540546.6529267

# %%
# datetimeモジュールをインポート
import datetime

# 指定した日時を取得する
date_time = datetime.datetime.strptime("2015-03-19 12:15:30", "%Y-%m-%d %H:%M:%S")

# 取得した日付date_timeの日時を特定のフォーマットで出力する
print(date_time.strftime("%Y年%m月%d日%H時%M分%S秒"))
# Out:
# 2015年03月19日12時15分30秒

# %%
# datetimeモジュールをインポート
import datetime

# 指定した日時を取得する
date_time = datetime.datetime.strptime("2015-03-19 12:15:30", "%Y-%m-%d %H:%M:%S")

print(date_time)

# 年,月,日,時,分,秒だけをそれぞれ取り出すことも可能です
print(date_time.year)
print(date_time.month)
print(date_time.day)
print(date_time.hour)
print(date_time.minute)
print(date_time.second)
# Out:
# 2015-03-19 12:15:30
# 2015
# 3
# 19
# 12
# 15
# 30

# %%
# datetimeモジュールをインポート
import datetime

# 現在時刻を取得する
now = datetime.datetime.now()

# 指定した日時を取得する
date_time = datetime.datetime.strptime("2015-03-19 12:15:30", "%Y-%m-%d %H:%M:%S")

# 2つのdatetimeの差を取得し、変数intervalに代入する（interval＝間隔）
interval = now - date_time

# 取得した日時の差を特定のフォーマットで出力する
print(f"総日数は{interval.days}日です。")
# Out:
# 総日数は4002日です。

# %%
# datetimeモジュールをインポート
import datetime

# 現在時刻を取得する
now = datetime.datetime.now()

# 指定した日時を取得する
date_time = datetime.datetime.strptime("2015-03-19 12:15:30", "%Y-%m-%d %H:%M:%S")

# 2つのdatetimeの差を取得し、変数intervalに代入する（interval＝間隔）
interval = now - date_time

# 取得した日時の差を特定のフォーマットで出力する
print(f"総日数は{interval.days}日です。")
# Out:
# 総日数は4002日です。

# %%
# datetimeモジュールをインポート
import datetime

# 現在時刻を取得する
now = datetime.datetime.now()

# 1年間の日数差を変数td_1yに代入する
td_1y = datetime.timedelta(days=365)

# 現在の日時に1年を加算し、変数addに代入する
add = now + td_1y

# 3日間の日数差を変数td_3dに代入する
td_3d = datetime.timedelta(days=3)

# 現在の日時から3日を減算し、変数subに代入する（sub＝「減算」を意味するsubtractionの略）
sub = now - td_3d

# 加算・減算した日時を特定のフォーマットで出力する
print(add.strftime("現在から1年後は%Y年%m月%d日%H時%M分%S秒です。"))
print(sub.strftime("現在から3日前は%Y年%m月%d日%H時%M分%S秒です。"))
# Out:
# 現在から1年後は2027年03月03日12時31分07秒です。
# 現在から3日前は2026年02月28日12時31分07秒です。

# %%
# Humanクラスの定義
class Human:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    # 20歳以上かどうかを判定するメソッド
    def check_adult(self):
        if self.age >= 20:
            print(self.name, "は大人です。")
        else:
            print(self.name, "は大人ではありません。")


# 複数のインスタンスを作成
human1 = Human("侍太郎", 25)
human2 = Human("侍花子", 18)
human3 = Human("侍一郎", 30)

# リストに追加
humans = [human1, human2, human3]

# リストの要素数分だけメソッドを呼び出す
for person in humans:
    person.check_adult()
# Out:
# 侍太郎 は大人です。
# 侍花子 は大人ではありません。
# 侍一郎 は大人です。

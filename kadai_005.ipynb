# %%
print(1+2)
# Out:
# 3

# %%
age = 18 # 年齢

if age < 20:
    # 未成年の場合
    print("ジュースで乾杯！")
else:
    # 成年の場合
    print("お酒で乾杯！")
# Out:
# ジュースで乾杯！

# %%
if age < 20:
    # 未成年の場合
    print("ジュースで乾杯！")
# Out:
#   File "/tmp/ipython-input-2120970045.py", line 1
#     if( age < 20 )
#                   ^
# SyntaxError: expected ':'

# %%
print("今日の天気は" + "晴れ")
print("今日の天気は" "曇り")
# Out:
# 今日の天気は晴れ
# 今日の天気は曇り

# %%
print("降水確率" + str(50) + "％" )
# Out:
# 降水確率50％

# %%
user_name = "侍太郎"
print(user_name)
# Out:
# 侍太郎

# %%
user_name = "侍太郎"
print(user_name)

user_name = "侍花子"
print(user_name)
# Out:
# 侍太郎
# 侍花子

# %%
last_name   = "侍"
first_name  = "太郎"
sister_name = "花子"

# 3つの変数を文字列内に埋め込んで表示
print(f"私の名前は{last_name}{first_name}です。妹の名前は{sister_name}です。")
# Out:
# 私の名前は侍太郎です。妹の名前は花子です。

# %%
top_side = 10
bottom_side = 20
height = 5

# 台形の面積を計算
area = (top_side + bottom_side) * height / 2

print(f"台形の面積は{area}㎠です。")
# Out:
#   File "/tmp/ipython-input-20133336.py", line 1
#     上辺：10cm
#       ^
# SyntaxError: invalid character '：' (U+FF1A)

# %%
top_side = 10
bottom_side = 20
height = 5

# 台形の面積を計算
area = (top_side + bottom_side) * height / 2

print(f"台形の面積は{area}㎠です。")
# Out:
# 台形の面積は75.0㎠です。
